# %% [markdown]
# # Section 1.2: Datasets
#
# In this section we introduce how to effectively create and read a dataset. We classified datasets in three formats:
#
# * **Raw Data:** raw data are available the same way they were collected. For example: PE executables, ELF or APK packages;
# * **Attributes:** filtered metadata extracted from the raw data with less noise and focus on the data that really matters. For example: CSV with metadata, execution logs of a sofware or data extracted from its header;
# * **Features:** features extracted from the attributes or raw data ready to be used in a classifier. For example: feature vectors extracted from the attributes collected before.
#
# With these definitions in mind, we will first introduce how to extract attributes from raw data.

# %% [markdown]
# ## Requirements:
#
# * **Python Version**: make sure you are using **Python 3.5 or higher**.
# * **Libraries:** all the python libraries used can be found in the file "requirements.txt". To install them, just run the following command (using pip):
# > *pip install -r requirements.txt*
# * **Datasets:** the datasets located at folder "./datasets/" are going to be used in our entire course. They are all in .zip extension. When extracting, make sure the .csv are located in this same folder. To extract, use the following command from a terminal:
# > *unzip \<filename\>.zip*.

# %% [markdown]
# ## Extracting Attributes from PE Files
#
# There are two ways to extract attributes from softwares: statically and dynamically.

# %% [markdown]
# ### Static Attributes
#
# To extract static attributes from PE files, we are going to use the library [pefile](https://github.com/erocarrera/pefile). Most of the information contained in the PE headers, sections and their data are easily accessible by it.
#
# Here is an example using one PE sample, located at "/datasets/samples/pe/".

# %%
import pefile
# file location
file_location = "./datasets/samples/pe/WinRAR.exe"
# open file using pefile
pe = pefile.PE(file_location)

# %% [markdown]
# Now that we have our PE file loaded, let's get its header attributes:

# %%
# get attributes from file
print(pe.FILE_HEADER)
# get timedate stamp from file header (if you want any other attribute, just change "NumberOfSections" to any other attribute listed in previous print)
print(pe.FILE_HEADER.NumberOfSections)
# Out:
# [IMAGE_FILE_HEADER]
# 0x114      0x0   Machine:                       0x8664
# 0x116      0x2   NumberOfSections:              0x8
# 0x118      0x4   TimeDateStamp:                 0x5C72EA4B [Sun Feb 24 19:02:35 2019 UTC]
# 0x11C      0x8   PointerToSymbolTable:          0x0
# 0x120      0xC   NumberOfSymbols:               0x0
# 0x124      0x10  SizeOfOptionalHeader:          0xF0
# 0x126      0x12  Characteristics:               0x22
# 8

# %% [markdown]
# It is also possible to get attributes from the optional header:

# %%
# print attributes from optional header
print(pe.OPTIONAL_HEADER)
# get size of code from optional header (if you want any other attribute, just change "SizeOfCode" to any other attribute listed in previous print)
print(pe.OPTIONAL_HEADER.SizeOfCode)
# Out:
# [IMAGE_OPTIONAL_HEADER64]
# 0x128      0x0   Magic:                         0x20B
# 0x12A      0x2   MajorLinkerVersion:            0xE
# 0x12B      0x3   MinorLinkerVersion:            0x0
# 0x12C      0x4   SizeOfCode:                    0x10C800
# 0x130      0x8   SizeOfInitializedData:         0x1BDA00
# 0x134      0xC   SizeOfUninitializedData:       0x0
# 0x138      0x10  AddressOfEntryPoint:           0xF1588
# 0x13C      0x14  BaseOfCode:                    0x1000
# 0x140      0x18  ImageBase:                     0x140000000
# 0x148      0x20  SectionAlignment:              0x1000
# 0x14C      0x24  FileAlignment:                 0x200
# 0x150      0x28  MajorOperatingSystemVersion:   0x5
# 0x152      0x2A  MinorOperatingSystemVersion:   0x2
# 0x154      0x2C  MajorImageVersion:             0x0
# 0x156      0x2E  MinorImageVersion:             0x0
# 0x158      0x30  MajorSubsystemVersion:         0x5
# 0x15A      0x32  MinorSubsystemVersion:         0x2
# 0x15C      0x34  Reserved1:                     0x0
# 0x160      0x38  SizeOfImage:                   0x2D0000
# 0x164      0x3C  SizeOfHeaders:                 0x400
# 0x168      0x40  CheckSum:                      0x234A84
# 0x16C      0x44  Subsystem:                     0x2
# 0x16E      0x46  DllCharacteristics:            0x8160
# 0x170      0x48  SizeOfStackReserve:            0x100000
# 0x178      0x50  SizeOfStackCommit:             0x1000
# 0x180      0x58  SizeOfHeapReserve:             0x100000
# 0x188      0x60  SizeOfHeapCommit:              0x1000
# 0x190      0x68  LoaderFlags:                   0x0
# 0x194      0x6C  NumberOfRvaAndSizes:           0x10
# 1099776

# %% [markdown]
# Getting imported DLLs:

# %%
# get imported dlls:
dlls = []
# walk in DIRECTORY_ENTRY_IMPORT
for d in pe.DIRECTORY_ENTRY_IMPORT:
    # append dll to dlls list
    dlls.append(d.dll)
# print dlls list
print(dlls)
# Out:
# [b'KERNEL32.dll', b'USER32.dll', b'GDI32.dll', b'COMDLG32.dll', b'ADVAPI32.dll', b'SHELL32.dll', b'ole32.dll', b'OLEAUT32.dll', b'SHLWAPI.dll', b'POWRPROF.dll', b'COMCTL32.dll', b'UxTheme.dll', b'gdiplus.dll', b'MSIMG32.dll']

# %% [markdown]
# Getting imported API calls from these DLLs:

# %%
# get used api calls
symbols = []
# walk in DIRECTORY_ENTRY_IMPORT
for i in pe.DIRECTORY_ENTRY_IMPORT:
    # walk in imported symbols
    for s in i.imports:
        # check if symbol is valid
        if s.name != None:
            # append to sybols list
            symbols.append(s.name)
# print symbols
print(symbols)
# Out:
# [b'DeviceIoControl', b'BackupRead', b'BackupSeek', b'GetShortPathNameW', b'GetLongPathNameW', b'GetFileType', b'GetStdHandle', b'FlushFileBuffers', b'GetFileTime', b'GetDiskFreeSpaceExW', b'GetVersionExW', b'GetCurrentDirectoryW', b'GetFullPathNameW', b'FoldStringW', b'LoadResource', b'SizeofResource', b'FindResourceW', b'LoadLibraryExW', b'CompareStringA', b'GetCurrentThread', b'SetThreadPriority', b'SetThreadExecutionState', b'CreateEventW', b'GetSystemDirectoryW', b'SetCurrentDirectoryW', b'GetFullPathNameA', b'SetPriorityClass', b'GetProcessAffinityMask', b'CreateThread', b'InitializeCriticalSection', b'EnterCriticalSection', b'LeaveCriticalSection', b'DeleteCriticalSection', b'SetEvent', b'ResetEvent', b'ReleaseSemaphore', b'CreateSemaphoreW', b'GetSystemTime', b'TzSpecificLocalTimeToSystemTime', b'GetCPInfo', b'IsDBCSLeadByte', b'WideCharToMultiByte', b'CompareStringW', b'GetModuleHandleExW', b'GetCompressedFileSizeW', b'EnumResourceNamesW', b'EnumResourceLanguagesW', b'BeginUpdateResourceW', b'UpdateResourceW', b'EndUpdateResourceW', b'GetLocaleInfoW', b'GetNumberFormatW', b'GetLogicalDrives', b'LockResource', b'SuspendThread', b'ResumeThread', b'GetStartupInfoW', b'GetCurrentThreadId', b'Beep', b'CopyFileW', b'FormatMessageW', b'SetErrorMode', b'GetPriorityClass', b'WaitForMultipleObjects', b'MulDiv', b'CompareFileTime', b'FindNextChangeNotification', b'GetProcessHeap', b'SetEnvironmentVariableA', b'FreeEnvironmentStringsW', b'GetEnvironmentStringsW', b'GetCommandLineA', b'IsValidCodePage', b'FindNextFileA', b'FindFirstFileExA', b'GetStringTypeW', b'WriteConsoleW', b'SetStdHandle', b'LCMapStringW', b'HeapReAlloc', b'GetModuleFileNameA', b'ExitProcess', b'GetConsoleCP', b'ReadConsoleW', b'GetConsoleMode', b'SetFilePointerEx', b'FreeLibraryAndExitThread', b'ExitThread', b'QueryPerformanceFrequency', b'EncodePointer', b'TlsFree', b'TlsSetValue', b'TlsGetValue', b'TlsAlloc', b'InitializeCriticalSectionAndSpinCount', b'RtlUnwindEx', b'RaiseException', b'RtlPcToFileHeader', b'InitializeSListHead', b'QueryPerformanceCounter', b'IsDebuggerPresent', b'WaitForSingleObjectEx', b'IsProcessorFeaturePresent', b'TerminateProcess', b'SetUnhandledExceptionFilter', b'UnhandledExceptionFilter', b'RtlVirtualUnwind', b'RtlLookupFunctionEntry', b'RtlCaptureContext', b'GetFileInformationByHandle', b'GetLocalTime', b'FindCloseChangeNotification', b'FindFirstChangeNotificationW', b'ExpandEnvironmentStringsW', b'SystemTimeToFileTime', b'SystemTimeToTzSpecificLocalTime', b'FindNextFileW', b'GetDiskFreeSpaceW', b'CreateHardLinkW', b'SetLastError', b'DosDateTimeToFileTime', b'LocalFileTimeToFileTime', b'HeapFree', b'HeapAlloc', b'HeapDestroy', b'HeapCreate', b'DeleteFileW', b'SetFileAttributesW', b'CreateFileW', b'RemoveDirectoryW', b'CreateDirectoryW', b'LoadLibraryW', b'GetSystemTimeAsFileTime', b'SetFileTime', b'SetFilePointer', b'SetEndOfFile', b'ReadFile', b'WriteFile', b'GetFileSize', b'FreeLibrary', b'MoveFileW', b'GetTickCount', b'GetCPInfoExW', b'GetOEMCP', b'GetACP', b'GetVolumeInformationW', b'GetDriveTypeW', b'Sleep', b'GetCurrentProcessId', b'GetCurrentProcess', b'CreateMutexW', b'ReleaseMutex', b'GetLastError', b'GlobalFree', b'GlobalUnlock', b'GlobalLock', b'GlobalSize', b'GlobalAlloc', b'HeapSize', b'MultiByteToWideChar', b'GetVersionExA', b'GetModuleHandleW', b'GetProcAddress', b'GetTempPathW', b'OpenFileMappingW', b'CreateFileMappingW', b'UnmapViewOfFile', b'MapViewOfFile', b'CloseHandle', b'WaitForSingleObject', b'GetCommandLineW', b'GetModuleFileNameW', b'GetDateFormatW', b'GetTimeFormatW', b'FindFirstFileW', b'FileTimeToSystemTime', b'FileTimeToLocalFileTime', b'FindClose', b'GetThreadPriority', b'GetFileAttributesW', b'CopyImage', b'FindWindowExW', b'FillRect', b'MessageBoxW', b'CreateIcon', b'EnumWindows', b'SetForegroundWindow', b'IsCharAlphaW', b'FlashWindow', b'CopyRect', b'RegisterClassExW', b'GetSysColor', b'ValidateRect', b'DrawIconEx', b'LoadImageW', b'SystemParametersInfoW', b'GetSystemMenu', b'KillTimer', b'SetTimer ...

# %% [markdown]
# Print all PE header information:

# %%
print(pe.dump_info())
# Out:
# ----------DOS_HEADER----------
#
# [IMAGE_DOS_HEADER]
# 0x0        0x0   e_magic:                       0x5A4D
# 0x2        0x2   e_cblp:                        0x90
# 0x4        0x4   e_cp:                          0x3
# 0x6        0x6   e_crlc:                        0x0
# 0x8        0x8   e_cparhdr:                     0x4
# 0xA        0xA   e_minalloc:                    0x0
# 0xC        0xC   e_maxalloc:                    0xFFFF
# 0xE        0xE   e_ss:                          0x0
# 0x10       0x10  e_sp:                          0xB8
# 0x12       0x12  e_csum:                        0x0
# 0x14       0x14  e_ip:                          0x0
# 0x16       0x16  e_cs:                          0x0
# 0x18       0x18  e_lfarlc:                      0x40
# 0x1A       0x1A  e_ovno:                        0x0
# 0x1C       0x1C  e_res:
# 0x24       0x24  e_oemid:                       0x0
# 0x26       0x26  e_oeminfo:                     0x0
# 0x28       0x28  e_res2:
# 0x3C       0x3C  e_lfanew:                      0x110
#
# ----------NT_HEADERS----------
#
# [IMAGE_NT_HEADERS]
# 0x110      0x0   Signature:                     0x4550
#
# ----------FILE_HEADER----------
#
# [IMAGE_FILE_HEADER]
# 0x114      0x0   Machine:                       0x8664
# 0x116      0x2   NumberOfSections:              0x8
# 0x118      0x4   TimeDateStamp:                 0x5C72EA4B [Sun Feb 24 19:02:35 2019 UTC]
# 0x11C      0x8   PointerToSymbolTable:          0x0
# 0x120      0xC   NumberOfSymbols:               0x0
# 0x124      0x10  SizeOfOptionalHeader:          0xF0
# 0x126      0x12  Characteristics:               0x22
# Flags: IMAGE_FILE_EXECUTABLE_IMAGE, IMAGE_FILE_LARGE_ADDRESS_AWARE
#
# ----------OPTIONAL_HEADER----------
#
# [IMAGE_OPTIONAL_HEADER64]
# 0x128      0x0   Magic:                         0x20B
# 0x12A      0x2   MajorLinkerVersion:            0xE
# 0x12B      0x3   MinorLinkerVersion:            0x0
# 0x12C      0x4   SizeOfCode:                    0x10C800
# 0x130      0x8   SizeOfInitializedData:         0x1BDA00
# 0x134      0xC   SizeOfUninitializedData:       0x0
# 0x138      0x10  AddressOfEntryPoint:           0xF1588
# 0x13C      0x14  BaseOfCode:                    0x1000
# 0x140      0x18  ImageBase:                     0x140000000
# 0x148      0x20  SectionAlignment:              0x1000
# 0x14C      0x24  FileAlignment:                 0x200
# 0x150      0x28  MajorOperatingSystemVersion:   0x5
# 0x152      0x2A  MinorOperatingSystemVersion:   0x2
# 0x154      0x2C  MajorImageVersion:             0x0
# 0x156      0x2E  MinorImageVersion:             0x0
# 0x158      0x30  MajorSubsystemVersion:         0x5
# 0x15A      0x32  MinorSubsystemVersion:         0x2
# 0x15C      0x34  Reserved1:                     0x0
# 0x160      0x38  SizeOfImage:                   0x2D0000
# 0x164      0x3C  SizeOfHeaders:                 0x400
# 0x168      0x40  CheckSum:                      0x234A84
# 0x16C      0x44  Subsystem:                     0x2
# 0x16E      0x46  DllCharacteristics:            0x8160
# 0x170      0x48  SizeOfStackReserve:            0x100000
# 0x178      0x50  SizeOfStackCommit:             0x1000
# 0x180      0x58  SizeOfHeapReserve:             0x100000
# 0x188      0x60  SizeOfHeapCommit:              0x1000
# 0x190      0x68  LoaderFlags:                   0x0
# 0x194      0x6C  NumberOfRvaAndSizes:           0x10
# DllCharacteristics: IMAGE_DLLCHARACTERISTICS_DYNAMIC_BASE, IMAGE_DLLCHARACTERISTICS_HIGH_ENTROPY_VA, IMAGE_DLLCHARACTERISTICS_NX_COMPAT, IMAGE_DLLCHARACTERISTICS_TERMINAL_SERVER_AWARE
#
# ----------PE Sections----------
#
# [IMAGE_SECTION_HEADER]
# 0x218      0x0   Name:                          .text
# 0x220      0x8   Misc:                          0x10C665
# 0x220      0x8   Misc_PhysicalAddress:          0x10C665
# 0x220      0x8   Misc_VirtualSize:              0x10C665
# 0x224      0xC   VirtualAddress:                0x1000
# 0x228      0x10  SizeOfRawData:                 0x10C800
# 0x22C      0x14  PointerToRawData:              0x400
# 0x230      0x18  PointerToRelocations:          0x0
# 0x234      0x1C  PointerToLinenumbers:          0x0
# 0x238      0x20  NumberOfRelocations:           0x0
# 0x23A      0x22  NumberOfLinenumbers:           0x0
# 0x23C      0x24  Characteristics:               0x60000020
# Flags: IMAGE_SCN_CNT_CODE, IMAGE_SCN_MEM_EXECUTE, IMAGE_SCN_MEM_READ
# Entropy: 6.507820 (Min=0.0, Max=8.0)
# MD5     hash: c8c089b0a0bb80671032498f0194062d
# SHA-1   hash: 57a8afc28890f4d065b90326cce270af65c91fcf
# SHA-256 hash: 8117a372af3f86bc21e8475f3d704efc47aa69a1c3377e50c2e0c7ea00f3fc5a
# SHA-512 hash: 0f82e2b10fbf9dd260e9e199e689aaddd5f0d8fba54d17b323debaf501cc91b993a5f789fa8cbd9d6c5078c355572419f74bf05c0005c53dbf7ac7019cb2970a
#
# [IMAGE_SECTION_HEADER]
# 0x240      0x0   Name:                          .rdata
# 0x248      0x8   Misc:                          0x2E574
# 0x248      0x8   Misc_PhysicalAddress:          0x2E574
# 0x248      0x8   Misc_VirtualSize:              0x2E574
# 0x24C      0xC   VirtualAddress:                0x10E000
# 0x250      0x10  SizeOfRawData:                 0x2E600
# 0x254      0x14  PointerToRawData:              0x10CC00
# 0x258      0x18  PointerToRelocations:          0x0
# 0x25C      0x1C  PointerToLinenumbers:          0x0
# 0x260      0x20  NumberOfRelocations:           0x0
# 0x262      0x22  NumberOfLinenumbers:           0x0
# 0x264      0x24  Characteristics:               0x40000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ
# Entropy: 4.925351 (Min=0.0, Max=8.0)
# MD5     hash: 6f0dda1643ff8053e36aa91a851da424
# SHA-1   hash: 468ad86c9eaee97eef3fc8609c5a68179d4ed100
# SHA-256 hash: 7483458f6dcbf896fa567bb6364db595e8e51614a5729ac84a83434fac73dbad
# SHA-512 hash: 8a436fcfcb23ba277d957da3796f71a7740f6c1d0c0d4f4340859eb5f57d3c8a09b48bcd1140782a317581c2cbd2e85b1b33db78babfde2dc0f10da0d6d62609
#
# [IMAGE_SECTION_HEADER]
# 0x268      0x0   Name:                          .data
# 0x270      0x8   Misc:                          0xA6A1C
# 0x270      0x8   Misc_PhysicalAddress:          0xA6A1C
# 0x270      0x8   Misc_VirtualSize:              0xA6A1C
# 0x274      0xC   VirtualAddress:                0x13D000
# 0x278      0x10  SizeOfRawData:                 0x4E00
# 0x27C      0x14  PointerToRawData:              0x13B200
# 0x280      0x18  PointerToRelocations:          0x0
# 0x284      0x1C  PointerToLinenumbers:          0x0
# 0x288      0x20  NumberOfRelocations:           0x0
# 0x28A      0x22  NumberOfLinenumbers:           0x0
# 0x28C      0x24  Characteristics:               0xC0000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ, IMAGE_SCN_MEM_WRITE
# Entropy: 2.781035 (Min=0.0, Max=8.0)
# MD5     hash: bce3e7f9f48ba0be501f4a056199dae1
# SHA-1   hash: 37da545651212d559a827eb201a230ac70365ed7
# SHA-256 hash: cad3efef1d13267839bd5cdb84b7efba3272e27f9c3dea7da12fc8c96b2cd948
# SHA-512 hash: d3473923c29800cbb5aae98b8ccda374e4ae8e176da89220cadcbbfe8e78e08fd9af077c4855b2c84be5426490c634cf691fd6b58b823791e3e6e7ed52e3859e
#
# [IMAGE_SECTION_HEADER]
# 0x290      0x0   Name:                          .pdata
# 0x298      0x8   Misc:                          0x9174
# 0x298      0x8   Misc_PhysicalAddress:          0x9174
# 0x298      0x8   Misc_VirtualSize:              0x9174
# 0x29C      0xC   VirtualAddress:                0x1E4000
# 0x2A0      0x10  SizeOfRawData:                 0x9200
# 0x2A4      0x14  PointerToRawData:              0x140000
# 0x2A8      0x18  PointerToRelocations:          0x0
# 0x2AC      0x1C  PointerToLinenumbers:          0x0
# 0x2B0      0x20  NumberOfRelocations:           0x0
# 0x2B2      0x22  NumberOfLinenumbers:           0x0
# 0x2B4      0x24  Characteristics:               0x40000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ
# Entropy: 6.071522 (Min=0.0, Max=8.0)
# MD5     hash: 230d8a634568fb3988bc242ab1771ee7
# SHA-1   hash: c9aacb7fa530468917e24b9bb52911c35a71ec21
# SHA-256 hash: c66dca2638d426510cbedbcbfb220fe0657634dfd0d4c3f641a6e82f073e6c91
# SHA-512 hash: 218a28c08e85ba521284ffbedd209fd13bb1f63bed48990035d07b5e2f5bd41ed443154b608aa93068eff5eb694677de2c1b1683f044d4a12506e3a6b0ffa42c
#
# [IMAGE_SECTION_HEADER]
# 0x2B8      0x0   Name:                          .gfids
# 0x2C0      0x8   Misc:                          0xE0
# 0x2C0      0x8   Misc_PhysicalAddress:          0xE0
# 0x2C0      0x8   Misc_VirtualSize:              0xE0
# 0x2C4      0xC   VirtualAddress:                0x1EE000
# 0x2C8      0x10  SizeOfRawData:                 0x200
# 0x2CC      0x14  PointerToRawData:              0x149200
# 0x2D0      0x18  PointerToRelocations:          0x0
# 0x2D4      0x1C  PointerToLinenumbers:          0x0
# 0x2D8      0x20  NumberOfRelocations:           0x0
# 0x2DA      0x22  NumberOfLinenumbers:           0x0
# 0x2DC      0x24  Characteristics:               0x40000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ
# Entropy: 2.068285 (Min=0.0, Max=8.0)
# MD5     hash: 7a4878d991a85261f7c98bece0fce97d
# SHA-1   hash: eb49895e491b9dfbd778d1a9e713845e02592d7c
# SHA-256 hash: 18fcfc5ed64fb3d81264cb6f18e761c49e73c92c8e5be028927f8381d612b5b8
# SHA-512 hash: 2bc737085e96db192b4009da94ff8dd0a74acd4e99f7ee2cb2a72308383256642c5d1813f573dccb8e218a4e46571fff842014f33a9d3fd29e05526ff7fe7df7
#
# [IMAGE_SECTION_HEADER]
# 0x2E0      0x0   Name:                          .tls
# 0x2E8      0x8   Misc:                          0x9
# 0x2E8      0x8   Misc_PhysicalAddress:          0x9
# 0x2E8      0x8   Misc_VirtualSize:              0x9
# 0x2EC      0xC   VirtualAddress:                0x1EF000
# 0x2F0      0x10  SizeOfRawData:                 0x200
# 0x2F4      0x14  PointerToRawData:              0x149400
# 0x2F8      0x18  PointerToRelocations:          0x0
# 0x2FC      0x1C  PointerToLinenumbers:          0x0
# 0x300      0x20  NumberOfRelocations:           0x0
# 0x302      0x22  NumberOfLinenumbers:           0x0
# 0x304      0x24  Characteristics:               0xC0000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ, IMAGE_SCN_MEM_WRITE
# Entropy: 0.020393 (Min=0.0, Max=8.0)
# MD5     hash: 1f354d76203061bfdd5a53dae48d5435
# SHA-1   hash: aa0d33a0c854e073439067876e932688b65cb6a9
# SHA-256 hash: 4c6474903705cb450bb6434c29e8854f17d8324efca1fdb9ee9008599060883a
# SHA-512 hash: 25b2d39b2f149ed4337896d78e66b5a2cbbc96ff4318c86b1d6d64f41d0fe7f1fa01fb2507252e353b79ed8edd7eeee1043ea673e346870573ef2716d4958dea
#
# [IMAGE_SECTION_HEADER]
# 0x308      0x0   Name:                          .rsrc
# 0x310      0x8   Misc:                          0xDE150
# 0x310      0x8   Misc_PhysicalAddress:          0xDE150
# 0x310      0x8   Misc_VirtualSize:              0xDE150
# 0x314      0xC   VirtualAddress:                0x1F0000
# 0x318      0x10  SizeOfRawData:                 0xDE200
# 0x31C      0x14  PointerToRawData:              0x149600
# 0x320      0x18  PointerToRelocations:          0x0
# 0x324      0x1C  PointerToLinenumbers:          0x0
# 0x328      0x20  NumberOfRelocations:           0x0
# 0x32A      0x22  NumberOfLinenumbers:           0x0
# 0x32C      0x24  Characteristics:               0x40000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_READ
# Entropy: 7.256631 (Min=0.0, Max=8.0)
# MD5     hash: 9866a2ba8cd059f08256b2abfa23b399
# SHA-1   hash: 00f60894ec081ff56274af6a2efde1b89055ed83
# SHA-256 hash: 1345a0e6183c412fa764d25db2a358124e02f9ffc6445025fc9f911cffebe61e
# SHA-512 hash: d402b1ec3f789b4dadf98d70d166eeff7df00876b535879de96f6b27c3823457f79bfcbfc4d4fb0f66dd1cd445fc6d9e53a622440f32c86f7145878eb28f33c8
#
# [IMAGE_SECTION_HEADER]
# 0x330      0x0   Name:                          .reloc
# 0x338      0x8   Misc:                          0xE14
# 0x338      0x8   Misc_PhysicalAddress:          0xE14
# 0x338      0x8   Misc_VirtualSize:              0xE14
# 0x33C      0xC   VirtualAddress:                0x2CF000
# 0x340      0x10  SizeOfRawData:                 0x1000
# 0x344      0x14  PointerToRawData:              0x227800
# 0x348      0x18  PointerToRelocations:          0x0
# 0x34C      0x1C  PointerToLinenumbers:          0x0
# 0x350      0x20  NumberOfRelocations:           0x0
# 0x352      0x22  NumberOfLinenumbers:           0x0
# 0x354      0x24  Characteristics:               0x42000040
# Flags: IMAGE_SCN_CNT_INITIALIZED_DATA, IMAGE_SCN_MEM_DISCARDABLE, IMAGE_SCN_MEM_READ
# Entropy: 5.157699 (Min=0.0, Max=8.0)
# MD5     hash: e3d1f6292967b9f7545b33aa0d0596ef
# SHA-1   hash: 6f97aba32ac4bf8181fac4f8cd63946f6bb1848e
# SHA-256 hash: 41146fd1d0bb4c50cb4910bb4e3190b6de95e49bfba9097ffef11726f0ed31bb
# SHA-512 hash: 5c49e1b5ad89fba5b6b8e149dbedfeaf5329bc3237a6c7096f50aa9673b2df321ebd8b9baec996fbf70606ea505f76fc70356a6e510e6023f43d3ddf805d5b13
#
# ----------Directories----------
#
# [IMAGE_DIRECTORY_ENTRY_EXPORT]
# 0x198      0x0   VirtualAddress:                0x0
# 0x19C      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_IMPORT]
# 0x1A0      0x0   VirtualAddress:                0x1395A4
# 0x1A4      0x4   Size:                          0x12C
# [IMAGE_DIRECTORY_ENTRY_RESOURCE]
# 0x1A8      0x0   VirtualAddress:                0x1F0000
# 0x1AC      0x4   Size:                          0xDE150
# [IMAGE_DIRECTORY_ENTRY_EXCEPTION]
# 0x1B0      0x0   VirtualAddress:                0x1E4000
# 0x1B4      0x4   Size:                          0x9174
# [IMAGE_DIRECTORY_ENTRY_SECURITY]
# 0x1B8      0x0   VirtualAddress:                0x228800
# 0x1BC      0x4   Size:                          0x34D8
# [IMAGE_DIRECTORY_ENTRY_BASERELOC]
# 0x1C0      0x0   VirtualAddress:                0x2CF000
# 0x1C4      0x4   Size:                          0xE14
# [IMAGE_DIRECTORY_ENTRY_DEBUG]
# 0x1C8      0x0   VirtualAddress:                0x127440
# 0x1CC      0x4   Size:                          0x54
# [IMAGE_DIRECTORY_ENTRY_COPYRIGHT]
# 0x1D0      0x0   VirtualAddress:                0x0
# 0x1D4      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_GLOBALPTR]
# 0x1D8      0x0   VirtualAddress:                0x0
# 0x1DC      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_TLS]
# 0x1E0      0x0   VirtualAddress:                0x127538
# 0x1E4      0x4   Size:                          0x28
# [IMAGE_DIRECTORY_ENTRY_LOAD_CONFIG]
# 0x1E8      0x0   VirtualAddress:                0x1274A0
# 0x1EC      0x4   Size:                          0x94
# [IMAGE_DIRECTORY_ENTRY_BOUND_IMPORT]
# 0x1F0      0x0   VirtualAddress:                0x0
# 0x1F4      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_IAT]
# 0x1F8      0x0   VirtualAddress:                0x10E000
# 0x1FC      0x4   Size:                          0xE70
# [IMAGE_DIRECTORY_ENTRY_DELAY_IMPORT]
# 0x200      0x0   VirtualAddress:                0x0
# 0x204      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_COM_DESCRIPTOR]
# 0x208      0x0   VirtualAddress:                0x0
# 0x20C      0x4   Size:                          0x0
# [IMAGE_DIRECTORY_ENTRY_RESERVED]
# 0x210      0x0   VirtualAddress:                0x0
# 0x214      0x4   Size:                          0x0
#
# ----------Version Information----------
#
# [VS_VERSIONINFO]
# 0x21F7E8   0x0   Length:                        0x2E0
# 0x21F7EA   0x2   ValueLength:                   0x34
# 0x21F7EC   0x4   Type:                          0x0
#
# [VS_FIXEDFILEINFO]
# 0x21F810   0x0   Signature:                     0xFEEF04BD
# 0x21F814   0x4   StrucVersion:                  0x10000
# 0x21F818   0x8   FileVersionMS:                 0x50046
# 0x21F81C   0xC   FileVersionLS:                 0x0
# 0x21F820   0x10  ProductVersionMS:              0x50046
# 0x21F824   0x14  ProductVersionLS:              0x0
# 0x21F828   0x18  FileFlagsMask:                 0x0
# 0x21F82C   0x1C  FileFlags:                     0x0
# 0x21F830   0x20  FileOS:                        0x4
# 0x21F834   0x24  FileType:                      0x1
# 0x21F838   0x28  FileSubtype:                   0x0
# 0x21F83C   0x2C  FileDateMS:                    0x0
# 0x21F840   0x30  FileDateLS:                    0x0
#
# [StringFileInfo]
# 0x21F844   0x0   Length:                        0x23E
# 0x21F846   0x2   ValueLength:                   0x0
# 0x21F848   0x4   Type:                          0x1
#
#   [StringTable]
#   0x21F868   0x0   Length:                        0x21A
#   0x21F86A   0x2   ValueLength:                   0x0
#   0x21F86C   0x4   Type:                          0x1
#   LangID: 040904E4
#
#     CompanyName: Alexander Roshal
#     FileDescription: WinRAR archiver
#     FileVersion: 5.70.0
#     InternalName: WinRAR
#     LegalCopyright: Copyright \xc2\xa9 Alexander Roshal 1993-2019
#     OriginalFilename: WinRAR.exe
#     ProductName: WinRAR
#     ProductVersion: 5.70.0
#
# [VarFileInfo]
# 0x21FA84   0x0   Length:                        0x44
# 0x21FA86   0x2   ValueLength:                   0x0
# 0x21FA88   0x4   Type:                          0x1
#
#   [Var]
#   0x21FAA4   0x0   Length:                        0x24
#   0x21FAA6   0x2   ValueLength:                   0x4
#   0x21FAA8   0x4   Type:                          0x0
#     Translation: 0x0409 0x04e4
#
# ----------Imported symbols----------
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x1381A4   0x0   OriginalFirstThunk:            0x1398F0
# 0x1381A4   0x0   Characteristics:               0x1398F0
# 0x1381A8   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x1381AC   0x8   ForwarderChain:                0x0
# 0x1381B0   0xC   Name:                          0x13AF48
# 0x1381B4   0x10  FirstThunk:                    0x10E220
#
# KERNEL32.dll.DeviceIoControl Hint[225]
# KERNEL32.dll.BackupRead Hint[24]
# KERNEL32.dll.BackupSeek Hint[25]
# KERNEL32.dll.GetShortPathNameW Hint[616]
# KERNEL32.dll.GetLongPathNameW Hint[533]
# KERNEL32.dll.GetFileType Hint[506]
# KERNEL32.dll.GetStdHandle Hint[619]
# KERNEL32.dll.FlushFileBuffers Hint[349]
# KERNEL32.dll.GetFileTime Hint[505]
# KERNEL32.dll.GetDiskFreeSpaceExW Hint[469]
# KERNEL32.dll.GetVersionExW Hint[684]
# KERNEL32.dll.GetCurrentDirectoryW Hint[453]
# KERNEL32.dll.GetFullPathNameW Hint[514]
# KERNEL32.dll.FoldStringW Hint[354]
# KERNEL32.dll.LoadResource Hint[835]
# KERNEL32.dll.SizeofResource Hint[1215]
# KERNEL32.dll.FindResourceW Hint[340]
# KERNEL32.dll.LoadLibraryExW Hint[832]
# KERNEL32.dll.CompareStringA Hint[97]
# KERNEL32.dll.GetCurrentThread Hint[458]
# KERNEL32.dll.SetThreadPriority Hint[1190]
# KERNEL32.dll.SetThreadExecutionState Hint[1184]
# KERNEL32.dll.CreateEventW Hint[133]
# KERNEL32.dll.GetSystemDirectoryW Hint[631]
# KERNEL32.dll.SetCurrentDirectoryW Hint[1115]
# KERNEL32.dll.GetFullPathNameA Hint[511]
# KERNEL32.dll.SetPriorityClass Hint[1162]
# KERNEL32.dll.GetProcessAffinityMask Hint[589]
# KERNEL32.dll.CreateThread Hint[180]
# KERNEL32.dll.InitializeCriticalSection Hint[746]
# KERNEL32.dll.EnterCriticalSection Hint[242]
# KERNEL32.dll.LeaveCriticalSection Hint[827]
# KERNEL32.dll.DeleteCriticalSection Hint[210]
# KERNEL32.dll.SetEvent Hint[1127]
# KERNEL32.dll.ResetEvent Hint[1042]
# KERNEL32.dll.ReleaseSemaphore Hint[1025]
# KERNEL32.dll.CreateSemaphoreW Hint[174]
# KERNEL32.dll.GetSystemTime Hint[638]
# KERNEL32.dll.TzSpecificLocalTimeToSystemTime Hint[1246]
# KERNEL32.dll.GetCPInfo Hint[376]
# KERNEL32.dll.IsDBCSLeadByte Hint[768]
# KERNEL32.dll.WideCharToMultiByte Hint[1312]
# KERNEL32.dll.CompareStringW Hint[100]
# KERNEL32.dll.GetModuleHandleExW Hint[541]
# KERNEL32.dll.GetCompressedFileSizeW Hint[401]
# KERNEL32.dll.EnumResourceNamesW Hint[263]
# KERNEL32.dll.EnumResourceLanguagesW Hint[259]
# KERNEL32.dll.BeginUpdateResourceW Hint[56]
# KERNEL32.dll.UpdateResourceW Hint[1262]
# KERNEL32.dll.EndUpdateResourceW Hint[241]
# KERNEL32.dll.GetLocaleInfoW Hint[524]
# KERNEL32.dll.GetNumberFormatW Hint[570]
# KERNEL32.dll.GetLogicalDrives Hint[527]
# KERNEL32.dll.LockResource Hint[854]
# KERNEL32.dll.SuspendThread Hint[1224]
# KERNEL32.dll.ResumeThread Hint[1046]
# KERNEL32.dll.GetStartupInfoW Hint[618]
# KERNEL32.dll.GetCurrentThreadId Hint[459]
# KERNEL32.dll.Beep Hint[54]
# KERNEL32.dll.CopyFileW Hint[117]
# KERNEL32.dll.FormatMessageW Hint[356]
# KERNEL32.dll.SetErrorMode Hint[1126]
# KERNEL32.dll.GetPriorityClass Hint[577]
# KERNEL32.dll.WaitForMultipleObjects Hint[1286]
# KERNEL32.dll.MulDiv Hint[872]
# KERNEL32.dll.CompareFileTime Hint[96]
# KERNEL32.dll.FindNextChangeNotification Hint[328]
# KERNEL32.dll.GetProcessHeap Hint[593]
# KERNEL32.dll.SetEnvironmentVariableA Hint[1124]
# KERNEL32.dll.FreeEnvironmentStringsW Hint[359]
# KERNEL32.dll.GetEnvironmentStringsW Hint[481]
# KERNEL32.dll.GetCommandLineA Hint[396]
# KERNEL32.dll.IsValidCodePage Hint[780]
# KERNEL32.dll.FindNextFileA Hint[329]
# KERNEL32.dll.FindFirstFileExA Hint[313]
# KERNEL32.dll.GetStringTypeW Hint[624]
# KERNEL32.dll.WriteConsoleW Hint[1331]
# KERNEL32.dll.SetStdHandle Hint[1172]
# KERNEL32.dll.LCMapStringW Hint[815]
# KERNEL32.dll.HeapReAlloc Hint[730]
# KERNEL32.dll.GetModuleFileNameA Hint[537]
# KERNEL32.dll.ExitProcess Hint[287]
# KERNEL32.dll.GetConsoleCP Hint[416]
# KERNEL32.dll.ReadConsoleW Hint[961]
# KERNEL32.dll.GetConsoleMode Hint[434]
# KERNEL32.dll.SetFilePointerEx Hint[1141]
# KERNEL32.dll.FreeLibraryAndExitThread Hint[361]
# KERNEL32.dll.ExitThread Hint[288]
# KERNEL32.dll.QueryPerformanceFrequency Hint[938]
# KERNEL32.dll.EncodePointer Hint[238]
# KERNEL32.dll.TlsFree Hint[1236]
# KERNEL32.dll.TlsSetValue Hint[1238]
# KERNEL32.dll.TlsGetValue Hint[1237]
# KERNEL32.dll.TlsAlloc Hint[1235]
# KERNEL32.dll.InitializeCriticalSectionAndSpinCount Hint[747]
# KERNEL32.dll.RtlUnwindEx Hint[1061]
# KERNEL32.dll.RaiseException Hint[948]
# KERNEL32.dll.RtlPcToFileHeader Hint[1057]
# KERNEL32.dll.InitializeSListHead Hint[751]
# KERNEL32.dll.QueryPerformanceCounter Hint[937]
# KERNEL32.dll.IsDebuggerPresent Hint[770]
# KERNEL32.dll.WaitForSingleObjectEx Hint[1289]
# KERNEL32.dll.IsProcessorFeaturePresent Hint[774]
# KERNEL32.dll.TerminateProcess Hint[1230]
# KERNEL32.dll.SetUnhandledExceptionFilter Hint[1203]
# KERNEL32.dll.UnhandledExceptionFilter Hint[1250]
# KERNEL32.dll.RtlVirtualUnwind Hint[1062]
# KERNEL32.dll.RtlLookupFunctionEntry Hint[1055]
# KERNEL32.dll.RtlCaptureContext Hint[1048]
# KERNEL32.dll.GetFileInformationByHandle Hint[499]
# KERNEL32.dll.GetLocalTime Hint[521]
# KERNEL32.dll.FindCloseChangeNotification Hint[309]
# KERNEL32.dll.FindFirstChangeNotificationW Hint[311]
# KERNEL32.dll.ExpandEnvironmentStringsW Hint[291]
# KERNEL32.dll.SystemTimeToFileTime Hint[1227]
# KERNEL32.dll.SystemTimeToTzSpecificLocalTime Hint[1228]
# KERNEL32.dll.FindNextFileW Hint[331]
# KERNEL32.dll.GetDiskFreeSpaceW Hint[470]
# KERNEL32.dll.CreateHardLinkW Hint[147]
# KERNEL32.dll.SetLastError Hint[1152]
# KERNEL32.dll.DosDateTimeToFileTime Hint[232]
# KERNEL32.dll.LocalFileTimeToFileTime Hint[840]
# KERNEL32.dll.HeapFree Hint[727]
# KERNEL32.dll.HeapAlloc Hint[723]
# KERNEL32.dll.HeapDestroy Hint[726]
# KERNEL32.dll.HeapCreate Hint[725]
# KERNEL32.dll.DeleteFileW Hint[215]
# KERNEL32.dll.SetFileAttributesW Hint[1135]
# KERNEL32.dll.CreateFileW Hint[143]
# KERNEL32.dll.RemoveDirectoryW Hint[1030]
# KERNEL32.dll.CreateDirectoryW Hint[129]
# KERNEL32.dll.LoadLibraryW Hint[833]
# KERNEL32.dll.GetSystemTimeAsFileTime Hint[640]
# KERNEL32.dll.SetFileTime Hint[1144]
# KERNEL32.dll.SetFilePointer Hint[1140]
# KERNEL32.dll.SetEndOfFile Hint[1121]
# KERNEL32.dll.ReadFile Hint[963]
# KERNEL32.dll.WriteFile Hint[1332]
# KERNEL32.dll.GetFileSize Hint[503]
# KERNEL32.dll.FreeLibrary Hint[360]
# KERNEL32.dll.MoveFileW Hint[869]
# KERNEL32.dll.GetTickCount Hint[666]
# KERNEL32.dll.GetCPInfoExW Hint[378]
# KERNEL32.dll.GetOEMCP Hint[574]
# KERNEL32.dll.GetACP Hint[366]
# KERNEL32.dll.GetVolumeInformationW Hint[687]
# KERNEL32.dll.GetDriveTypeW Hint[474]
# KERNEL32.dll.Sleep Hint[1216]
# KERNEL32.dll.GetCurrentProcessId Hint[455]
# KERNEL32.dll.GetCurrentProcess Hint[454]
# KERNEL32.dll.CreateMutexW Hint[158]
# KERNEL32.dll.ReleaseMutex Hint[1021]
# KERNEL32.dll.GetLastError Hint[520]
# KERNEL32.dll.GlobalFree Hint[706]
# KERNEL32.dll.GlobalUnlock Hint[717]
# KERNEL32.dll.GlobalLock Hint[710]
# KERNEL32.dll.GlobalSize Hint[714]
# KERNEL32.dll.GlobalAlloc Hint[699]
# KERNEL32.dll.HeapSize Hint[732]
# KERNEL32.dll.MultiByteToWideChar Hint[873]
# KERNEL32.dll.GetVersionExA Hint[683]
# KERNEL32.dll.GetModuleHandleW Hint[542]
# KERNEL32.dll.GetProcAddress Hint[588]
# KERNEL32.dll.GetTempPathW Hint[652]
# KERNEL32.dll.OpenFileMappingW Hint[891]
# KERNEL32.dll.CreateFileMappingW Hint[140]
# KERNEL32.dll.UnmapViewOfFile Hint[1253]
# KERNEL32.dll.MapViewOfFile Hint[857]
# KERNEL32.dll.CloseHandle Hint[82]
# KERNEL32.dll.WaitForSingleObject Hint[1288]
# KERNEL32.dll.GetCommandLineW Hint[397]
# KERNEL32.dll.GetModuleFileNameW Hint[538]
# KERNEL32.dll.GetDateFormatW Hint[463]
# KERNEL32.dll.GetTimeFormatW Hint[670]
# KERNEL32.dll.FindFirstFileW Hint[319]
# KERNEL32.dll.FileTimeToSystemTime Hint[299]
# KERNEL32.dll.FileTimeToLocalFileTime Hint[298]
# KERNEL32.dll.FindClose Hint[308]
# KERNEL32.dll.GetThreadPriority Hint[661]
# KERNEL32.dll.GetFileAttributesW Hint[497]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x1381B8   0x0   OriginalFirstThunk:            0x139F88
# 0x1381B8   0x0   Characteristics:               0x139F88
# 0x1381BC   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x1381C0   0x8   ForwarderChain:                0x0
# 0x1381C4   0xC   Name:                          0x13B93A
# 0x1381C8   0x10  FirstThunk:                    0x10E8B8
#
# USER32.dll.CopyImage Hint[84]
# USER32.dll.FindWindowExW Hint[249]
# USER32.dll.FillRect Hint[246]
# USER32.dll.MessageBoxW Hint[537]
# USER32.dll.CreateIcon Hint[100]
# USER32.dll.EnumWindows Hint[242]
# USER32.dll.SetForegroundWindow Hint[665]
# USER32.dll.IsCharAlphaW Hint[456]
# USER32.dll.FlashWindow Hint[251]
# USER32.dll.CopyRect Hint[85]
# USER32.dll.RegisterClassExW Hint[593]
# USER32.dll.GetSysColor Hint[381]
# USER32.dll.ValidateRect Hint[804]
# USER32.dll.DrawIconEx Hint[200]
# USER32.dll.LoadImageW Hint[499]
# USER32.dll.SystemParametersInfoW Hint[756]
# USER32.dll.GetSystemMenu Hint[383]
# USER32.dll.KillTimer Hint[487]
# USER32.dll.SetTimer Hint[705]
# USER32.dll.MessageBoxIndirectW Hint[534]
# USER32.dll.CharUpperW Hint[60]
# USER32.dll.ExitWindowsEx Hint[245]
# USER32.dll.CharLowerA Hint[43]
# USER32.dll.LoadStringW Hint[510]
# USER32.dll.GetWindow Hint[400]
# USER32.dll.SetProcessDefaultLayout Hint[687]
# USER32.dll.CharToOemBuffW Hint[55]
# USER32.dll.OemToCharBuffA Hint[550]
# USER32.dll.OemToCharA Hint[549]
# USER32.dll.GetComboBoxInfo Hint[286]
# USER32.dll.RedrawWindow Hint[590]
# USER32.dll.MessageBeep Hint[529]
# USER32.dll.CharToOemA Hint[53]
# USER32.dll.EmptyClipboard Hint[213]
# USER32.dll.SetClipboardData Hint[652]
# USER32.dll.CloseClipboard Hint[73]
# USER32.dll.OpenClipboard Hint[554]
# USER32.dll.PeekMessageW Hint[567]
# USER32.dll.GetScrollInfo Hint[375]
# USER32.dll.EnableMenuItem Hint[214]
# USER32.dll.CheckMenuItem Hint[63]
# USER32.dll.GetFocus Hint[302]
# USER32.dll.MoveWindow Hint[543]
# USER32.dll.GetClientRect Hint[278]
# USER32.dll.GetWindowTextLengthW Hint[422]
# USER32.dll.EndPaint Hint[220]
# USER32.dll.BeginPaint Hint[14]
# USER32.dll.UpdateWindow Hint[793]
# USER32.dll.AppendMenuW Hint[10]
# USER32.dll.RegisterWindowMessageW Hint[615]
# USER32.dll.DrawMenuBar Hint[201]
# USER32.dll.wsprintfW Hint[827]
# USER32.dll.SetWindowLongPtrW Hint[715]
# USER32.dll.ScreenToClient Hint[625]
# USER32.dll.ClientToScreen Hint[71]
# USER32.dll.CallWindowProcW Hint[30]
# USER32.dll.PtInRect Hint[580]
# USER32.dll.SetMenuItemInfoW Hint[680]
# USER32.dll.GetMenuItemInfoW Hint[342]
# USER32.dll.InsertMenuItemW Hint[445]
# USER32.dll.TrackPopupMenu Hint[766]
# USER32.dll.DeleteMenu Hint[158]
# USER32.dll.GetMenuItemID Hint[340]
# USER32.dll.SetMenu Hint[674]
# USER32.dll.LoadMenuW Hint[507]
# USER32.dll.LoadAcceleratorsW Hint[489]
# USER32.dll.IsChild Hint[461]
# USER32.dll.RegisterClassW Hint[594]
# USER32.dll.PostQuitMessage Hint[571]
# USER32.dll.SetScrollRange Hint[696]
# USER32.dll.SetScrollPos Hint[695]
# USER32.dll.ScrollWindowEx Hint[629]
# USER32.dll.GetClipboardData Hint[280]
# USER32.dll.LoadIconW Hint[497]
# USER32.dll.CreateDialogParamW Hint[99]
# USER32.dll.GetMessageW Hint[351]
# USER32.dll.PostThreadMessageW Hint[573]
# USER32.dll.IsDialogMessageW Hint[465]
# USER32.dll.GetIconInfo Hint[309]
# USER32.dll.CreateIconIndirect Hint[103]
# USER32.dll.FindWindowW Hint[250]
# USER32.dll.RemovePropW Hint[621]
# USER32.dll.SendMessageW Hint[640]
# USER32.dll.DefWindowProcW Hint[156]
# USER32.dll.CreateWindowExW Hint[110]
# USER32.dll.DestroyWindow Hint[166]
# USER32.dll.SetFocus Hint[664]
# USER32.dll.GetWindowTextW Hint[423]
# USER32.dll.GetWindowLongW Hint[410]
# USER32.dll.SetWindowLongW Hint[716]
# USER32.dll.SetWindowPos Hint[718]
# USER32.dll.GetWindowPlacement Hint[415]
# USER32.dll.SetWindowPlacement Hint[717]
# USER32.dll.IsWindowVisible Hint[484]
# USER32.dll.DialogBoxParamW Hint[172]
# USER32.dll.GetPropW Hint[365]
# USER32.dll.SetPropW Hint[691]
# USER32.dll.GetForegroundWindow Hint[303]
# USER32.dll.TranslateAcceleratorW Hint[770]
# USER32.dll.CreateDialogIndirectParamW Hint[97]
# USER32.dll.GetLastActivePopup Hint[326]
# USER32.dll.GetMenuState Hint[344]
# USER32.dll.BringWindowToTop Hint[16]
# USER32.dll.DispatchMessageW Hint[175]
# USER32.dll.InsertMenuW Hint[446]
# USER32.dll.GetSubMenu Hint[380]
# USER32.dll.DestroyMenu Hint[164]
# USER32.dll.CreatePopupMenu Hint[107]
# USER32.dll.GetMenu Hint[333]
# USER32.dll.IsWindow Hint[479]
# USER32.dll.EndDialog Hint[218]
# USER32.dll.GetDlgItem Hint[297]
# USER32.dll.SetDlgItemTextW Hint[662]
# USER32.dll.GetDlgItemTextW Hint[300]
# USER32.dll.SendDlgItemMessageW Hint[631]
# USER32.dll.GetWindowRect Hint[416]
# USER32.dll.MapWindowPoints Hint[525]
# USER32.dll.GetParent Hint[358]
# USER32.dll.DestroyIcon Hint[163]
# USER32.dll.CheckDlgButton Hint[62]
# USER32.dll.PostMessageW Hint[570]
# USER32.dll.InvalidateRect Hint[450]
# USER32.dll.EnumChildWindows Hint[223]
# USER32.dll.GetClassNameW Hint[276]
# USER32.dll.ShowWindow Hint[743]
# USER32.dll.CharToOemBuffA Hint[54]
# USER32.dll.SetDlgItemInt Hint[660]
# USER32.dll.GetDlgItemInt Hint[298]
# USER32.dll.TranslateMessage Hint[772]
# USER32.dll.GetMenuItemCount Hint[339]
# USER32.dll.WaitForInputIdle Hint[814]
# USER32.dll.LoadCursorW Hint[495]
# USER32.dll.GetWindowThreadProcessId Hint[424]
# USER32.dll.WindowFromPoint Hint[820]
# USER32.dll.SetCursor Hint[654]
# USER32.dll.GetKeyState Hint[319]
# USER32.dll.RegisterClipboardFormatW Hint[596]
# USER32.dll.SystemParametersInfoA Hint[755]
# USER32.dll.GetDesktopWindow Hint[293]
# USER32.dll.GetWindowLongPtrW Hint[409]
# USER32.dll.IntersectRect Hint[449]
# USER32.dll.GetCursorPos Hint[290]
# USER32.dll.SetWindowTextW Hint[723]
# USER32.dll.ReleaseDC Hint[617]
# USER32.dll.GetDC Hint[291]
# USER32.dll.GetSystemMetrics Hint[384]
# USER32.dll.EnableWindow Hint[216]
# USER32.dll.IsIconic Hint[469]
# USER32.dll.IsWindowEnabled Hint[480]
# USER32.dll.IsDlgButtonChecked Hint[466]
# USER32.dll.CharLowerW Hint[46]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x1381CC   0x0   OriginalFirstThunk:            0x1397F8
# 0x1381CC   0x0   Characteristics:               0x1397F8
# 0x1381D0   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x1381D4   0x8   ForwarderChain:                0x0
# 0x1381D8   0xC   Name:                          0x13BB08
# 0x1381DC   0x10  FirstThunk:                    0x10E128
#
# GDI32.dll.TextOutA Hint[696]
# GDI32.dll.SetPixel Hint[667]
# GDI32.dll.Rectangle Hint[607]
# GDI32.dll.GetTextExtentPoint32W Hint[542]
# GDI32.dll.CreateSolidBrush Hint[84]
# GDI32.dll.CreateDIBSection Hint[53]
# GDI32.dll.GetPixel Hint[516]
# GDI32.dll.DPtoLP Hint[164]
# GDI32.dll.StretchBlt Hint[691]
# GDI32.dll.SetMapMode Hint[660]
# GDI32.dll.GetMapMode Hint[496]
# GDI32.dll.GetDeviceCaps Hint[459]
# GDI32.dll.CreateCompatibleBitmap Hint[47]
# GDI32.dll.CreateBitmap Hint[41]
# GDI32.dll.ExtTextOutW Hint[312]
# GDI32.dll.SetBkColor Hint[638]
# GDI32.dll.DeleteDC Hint[227]
# GDI32.dll.CreateCompatibleDC Hint[48]
# GDI32.dll.BitBlt Hint[19]
# GDI32.dll.GetObjectW Hint[509]
# GDI32.dll.TextOutW Hint[697]
# GDI32.dll.MoveToEx Hint[570]
# GDI32.dll.SetTextColor Hint[678]
# GDI32.dll.LineTo Hint[566]
# GDI32.dll.CreatePen Hint[75]
# GDI32.dll.GetTextFaceW Hint[548]
# GDI32.dll.GetTextMetricsW Hint[550]
# GDI32.dll.SelectObject Hint[631]
# GDI32.dll.DeleteObject Hint[230]
# GDI32.dll.CreateFontW Hint[65]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x1381E0   0x0   OriginalFirstThunk:            0x1397D0
# 0x1381E0   0x0   Characteristics:               0x1397D0
# 0x1381E4   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x1381E8   0x8   ForwarderChain:                0x0
# 0x1381EC   0xC   Name:                          0x13BB60
# 0x1381F0   0x10  FirstThunk:                    0x10E100
#
# COMDLG32.dll.GetOpenFileNameW Hint[12]
# COMDLG32.dll.GetSaveFileNameW Hint[14]
# COMDLG32.dll.CommDlgExtendedError Hint[4]
# COMDLG32.dll.ChooseFontW Hint[3]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x1381F4   0x0   OriginalFirstThunk:            0x1396D0
# 0x1381F4   0x0   Characteristics:               0x1396D0
# 0x1381F8   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x1381FC   0x8   ForwarderChain:                0x0
# 0x138200   0xC   Name:                          0x13BD50
# 0x138204   0x10  FirstThunk:                    0x10E000
#
# ADVAPI32.dll.AllocateAndInitializeSid Hint[32]
# ADVAPI32.dll.AccessCheck Hint[5]
# ADVAPI32.dll.OpenProcessToken Hint[503]
# ADVAPI32.dll.MapGenericMask Hint[483]
# ADVAPI32.dll.GetFileSecurityW Hint[304]
# ADVAPI32.dll.RegCloseKey Hint[560]
# ADVAPI32.dll.IsTextUnicode Hint[384]
# ADVAPI32.dll.RegSetValueExW Hint[638]
# ADVAPI32.dll.RegEnumValueW Hint[594]
# ADVAPI32.dll.RegEnumKeyExW Hint[591]
# ADVAPI32.dll.RegDeleteValueW Hint[584]
# ADVAPI32.dll.RegDeleteKeyW Hint[580]
# ADVAPI32.dll.RegCreateKeyExW Hint[569]
# ADVAPI32.dll.CheckTokenMembership Hint[81]
# ADVAPI32.dll.FreeSid Hint[288]
# ADVAPI32.dll.DuplicateToken Hint[222]
# ADVAPI32.dll.SetFileSecurityW Hint[682]
# ADVAPI32.dll.GetSecurityDescriptorLength Hint[330]
# ADVAPI32.dll.CryptGenRandom Hint[193]
# ADVAPI32.dll.CryptReleaseContext Hint[203]
# ADVAPI32.dll.CryptAcquireContextW Hint[177]
# ADVAPI32.dll.LookupPrivilegeValueW Hint[407]
# ADVAPI32.dll.AdjustTokenPrivileges Hint[31]
# ADVAPI32.dll.RegQueryValueExW Hint[622]
# ADVAPI32.dll.RegOpenKeyExW Hint[609]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x138208   0x0   OriginalFirstThunk:            0x139ED0
# 0x138208   0x0   Characteristics:               0x139ED0
# 0x13820C   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x138210   0x8   ForwarderChain:                0x0
# 0x138214   0xC   Name:                          0x13BEBE
# 0x138218   0x10  FirstThunk:                    0x10E800
#
# SHELL32.dll.FindExecutableW Hint[45]
# SHELL32.dll.DragFinish Hint[27]
# SHELL32.dll.DragQueryFileW Hint[31]
# SHELL32.dll.Shell_NotifyIconW Hint[302]
# SHELL32.dll.DragAcceptFiles Hint[26]
# SHELL32.dll.SHGetSpecialFolderLocation Hint[223]
# SHELL32.dll Ordinal[100] (Imported by Ordinal)
# SHELL32.dll.SHAddToRecentDocs Hint[112]
# SHELL32.dll.SHFileOperationW Hint[172]
# SHELL32.dll.SHGetFolderPathW Hint[195]
# SHELL32.dll.ShellExecuteExW Hint[289]
# SHELL32.dll.SHBrowseForFolderW Hint[123]
# SHELL32.dll.SHGetMalloc Hint[207]
# SHELL32.dll.SHChangeNotify Hint[127]
# SHELL32.dll.SHGetDesktopFolder Hint[182]
# SHELL32.dll.SHGetFolderLocation Hint[190]
# SHELL32.dll.SHGetPathFromIDListW Hint[215]
# SHELL32.dll.SHGetFileInfoW Hint[189]
# SHELL32.dll.ShellExecuteW Hint[290]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x13821C   0x0   OriginalFirstThunk:            0x13A4D8
# 0x13821C   0x0   Characteristics:               0x13A4D8
# 0x138220   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x138224   0x8   ForwarderChain:                0x0
# 0x138228   0xC   Name:                          0x13BFA4
# 0x13822C   0x10  FirstThunk:                    0x10EE08
#
# ole32.dll.RevokeDragDrop Hint[397]
# ole32.dll.RegisterDragDrop Hint[395]
# ole32.dll.OleUninitialize Hint[381]
# ole32.dll.OleInitialize Hint[358]
# ole32.dll.CLSIDFromString Hint[12]
# ole32.dll.CreateStreamOnHGlobal Hint[138]
# ole32.dll.CoTaskMemAlloc Hint[107]
# ole32.dll.CoInitializeEx Hint[67]
# ole32.dll.CoTaskMemFree Hint[108]
# ole32.dll.CoCreateInstance Hint[20]
# ole32.dll.OleSetClipboard Hint[377]
# ole32.dll.DoDragDrop Hint[144]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x138230   0x0   OriginalFirstThunk:            0x139EA8
# 0x138230   0x0   Characteristics:               0x139EA8
# 0x138234   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x138238   0x8   ForwarderChain:                0x0
# 0x13823C   0xC   Name:                          0x13BFAE
# 0x138240   0x10  FirstThunk:                    0x10E7D8
#
# OLEAUT32.dll.VariantClear Ordinal[9] (Imported by Ordinal)
# OLEAUT32.dll.SysAllocString Ordinal[2] (Imported by Ordinal)
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x138244   0x0   OriginalFirstThunk:            0x139F70
# 0x138244   0x0   Characteristics:               0x139F70
# 0x138248   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x13824C   0x8   ForwarderChain:                0x0
# 0x138250   0xC   Name:                          0x13BFE0
# 0x138254   0x10  FirstThunk:                    0x10E8A0
#
# SHLWAPI.dll.StrCmpLogicalW Hint[282]
# SHLWAPI.dll.SHAutoComplete Hint[164]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x138258   0x0   OriginalFirstThunk:            0x139EC0
# 0x138258   0x0   Characteristics:               0x139EC0
# 0x13825C   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x138260   0x8   ForwarderChain:                0x0
# 0x138264   0xC   Name:                          0x13BFFE
# 0x138268   0x10  FirstThunk:                    0x10E7F0
#
# POWRPROF.dll.SetSuspendState Hint[87]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x13826C   0x0   OriginalFirstThunk:            0x1397A0
# 0x13826C   0x0   Characteristics:               0x1397A0
# 0x138270   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x138274   0x8   ForwarderChain:                0x0
# 0x138278   0xC   Name:                          0x13C078
# 0x13827C   0x10  FirstThunk:                    0x10E0D0
#
# COMCTL32.dll.CreateStatusWindowW Hint[12]
# COMCTL32.dll.ImageList_Create Hint[84]
# COMCTL32.dll.ImageList_ReplaceIcon Hint[112]
# COMCTL32.dll.InitCommonControlsEx Hint[124]
# COMCTL32.dll.PropertySheetW Hint[134]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x138280   0x0   OriginalFirstThunk:            0x13A448
# 0x138280   0x0   Characteristics:               0x13A448
# 0x138284   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x138288   0x8   ForwarderChain:                0x0
# 0x13828C   0xC   Name:                          0x13C0A4
# 0x138290   0x10  FirstThunk:                    0x10ED78
#
# UxTheme.dll.IsThemeActive Hint[63]
# UxTheme.dll.IsAppThemed Hint[61]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x138294   0x0   OriginalFirstThunk:            0x13A460
# 0x138294   0x0   Characteristics:               0x13A460
# 0x138298   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x13829C   0x8   ForwarderChain:                0x0
# 0x1382A0   0xC   Name:                          0x13C1F2
# 0x1382A4   0x10  FirstThunk:                    0x10ED90
#
# gdiplus.dll.GdiplusShutdown Hint[628]
# gdiplus.dll.GdiplusStartup Hint[629]
# gdiplus.dll.GdipCreateHBITMAPFromBitmap Hint[95]
# gdiplus.dll.GdipCreateBitmapFromFileICM Hint[74]
# gdiplus.dll.GdipCreateBitmapFromStreamICM Hint[82]
# gdiplus.dll.GdipCreateBitmapFromFile Hint[73]
# gdiplus.dll.GdipCreateBitmapFromStream Hint[81]
# gdiplus.dll.GdipDisposeImage Hint[152]
# gdiplus.dll.GdipCloneImage Hint[54]
# gdiplus.dll.GdipFree Hint[237]
# gdiplus.dll.GdipAlloc Hint[33]
# gdiplus.dll.GdipCreateBitmapFromHBITMAP Hint[77]
# gdiplus.dll.GdipBitmapGetPixel Hint[42]
# gdiplus.dll.GdipBitmapSetPixel Hint[44]
#
# [IMAGE_IMPORT_DESCRIPTOR]
# 0x1382A8   0x0   OriginalFirstThunk:            0x139E98
# 0x1382A8   0x0   Characteristics:               0x139E98
# 0x1382AC   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x1382B0   0x8   ForwarderChain:                0x0
# 0x1382B4   0xC   Name:                          0x13C20E
# 0x1382B8   0x10  FirstThunk:                    0x10E7C8
#
# MSIMG32.dll.GradientFill Hint[2]
#
# ----------Resource directory----------
#
# [IMAGE_RESOURCE_DIRECTORY]
# 0x149600   0x0   Characteristics:               0x0
# 0x149604   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
# 0x149608   0x8   MajorVersion:                  0x0
# 0x14960A   0xA   MinorVersion:                  0x0
# 0x14960C   0xC   NumberOfNamedEntries:          0x1
# 0x14960E   0xE   NumberOfIdEntries:             0xA
#   Name: [PNG]
#   [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#   0x149610   0x0   Name:                          0x800040E8
#   0x149614   0x4   OffsetToData:                  0x80000068
#     [IMAGE_RESOURCE_DIRECTORY]
#     0x149668   0x0   Characteristics:               0x0
#     0x14966C   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#     0x149670   0x8   MajorVersion:                  0x0
#     0x149672   0xA   MinorVersion:                  0x0
#     0x149674   0xC   NumberOfNamedEntries:          0x0
#     0x149676   0xE   NumberOfIdEntries:             0x6F
#       Id: [0x65]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x149678   0x0   Name:                          0x65
#       0x14967C   0x4   OffsetToData:                  0x80000BB0
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x14A1B0   0x0   Characteristics:               0x0
#         0x14A1B4   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x14A1B8   0x8   MajorVersion:                  0x0
#         0x14A1BA   0xA   MinorVersion:                  0x0
#         0x14A1BC   0xC   NumberOfNamedEntries:          0x0
#         0x14A1BE   0xE   NumberOfIdEntries:             0x1
#         \--- LANG [9,1][LANG_ENGLISH,SUBLANG_ENGLISH_US]
#           [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#           0x14A1C0   0x0   Name:                          0x409
#           0x14A1C4   0x4   OffsetToData:                  0x2B78
#             [IMAGE_RESOURCE_DATA_ENTRY]
#             0x14C178   0x0   OffsetToData:                  0x1F4EA0
#             0x14C17C   0x4   Size:                          0x4101
#             0x14C180   0x8   CodePage:                      0x0
#             0x14C184   0xC   Reserved:                      0x0
#       Id: [0x66]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x149680   0x0   Name:                          0x66
#       0x149684   0x4   OffsetToData:                  0x80000BC8
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x14A1C8   0x0   Characteristics:               0x0
#         0x14A1CC   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x14A1D0   0x8   MajorVersion:                  0x0
#         0x14A1D2   0xA   MinorVersion:                  0x0
#         0x14A1D4   0xC   NumberOfNamedEntries:          0x0
#         0x14A1D6   0xE   NumberOfIdEntries:             0x1
#         \--- LANG [9,1][LANG_ENGLISH,SUBLANG_ENGLISH_US]
#           [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#           0x14A1D8   0x0   Name:                          0x409
#           0x14A1DC   0x4   OffsetToData:                  0x2B88
#             [IMAGE_RESOURCE_DATA_ENTRY]
#             0x14C188   0x0   OffsetToData:                  0x1F8FA8
#             0x14C18C   0x4   Size:                          0xDC20
#             0x14C190   0x8   CodePage:                      0x0
#             0x14C194   0xC   Reserved:                      0x0
#       Id: [0x6F]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x149688   0x0   Name:                          0x6F
#       0x14968C   0x4   OffsetToData:                  0x80000BE0
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x14A1E0   0x0   Characteristics:               0x0
#         0x14A1E4   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x14A1E8   0x8   MajorVersion:                  0x0
#         0x14A1EA   0xA   MinorVersion:                  0x0
#         0x14A1EC   0xC   NumberOfNamedEntries:          0x0
#         0x14A1EE   0xE   NumberOfIdEntries:             0x1
#         \--- LANG [9,1][LANG_ENGLISH,SUBLANG_ENGLISH_US]
#           [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#           0x14A1F0   0x0   Name:                          0x409
#           0x14A1F4   0x4   OffsetToData:                  0x2B98
#             [IMAGE_RESOURCE_DATA_ENTRY]
#             0x14C198   0x0   OffsetToData:                  0x206BC8
#             0x14C19C   0x4   Size:                          0xC9B
#             0x14C1A0   0x8   CodePage:                      0x0
#             0x14C1A4   0xC   Reserved:                      0x0
#       Id: [0x70]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x149690   0x0   Name:                          0x70
#       0x149694   0x4   OffsetToData:                  0x80000BF8
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x14A1F8   0x0   Characteristics:               0x0
#         0x14A1FC   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x14A200   0x8   MajorVersion:                  0x0
#         0x14A202   0xA   MinorVersion:                  0x0
#         0x14A204   0xC   NumberOfNamedEntries:          0x0
#         0x14A206   0xE   NumberOfIdEntries:             0x1
#         \--- LANG [9,1][LANG_ENGLISH,SUBLANG_ENGLISH_US]
#           [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#           0x14A208   0x0   Name:                          0x409
#           0x14A20C   0x4   OffsetToData:                  0x2BA8
#             [IMAGE_RESOURCE_DATA_ENTRY]
#             0x14C1A8   0x0   OffsetToData:                  0x207868
#             0x14C1AC   0x4   Size:                          0x1FAF
#             0x14C1B0   0x8   CodePage:                      0x0
#             0x14C1B4   0xC   Reserved:                      0x0
#       Id: [0x71]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x149698   0x0   Name:                          0x71
#       0x14969C   0x4   OffsetToData:                  0x80000C10
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x14A210   0x0   Characteristics:               0x0
#         0x14A214   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x14A218   0x8   MajorVersion:                  0x0
#         0x14A21A   0xA   MinorVersion:                  0x0
#         0x14A21C   0xC   NumberOfNamedEntries:          0x0
#         0x14A21E   0xE   NumberOfIdEntries:             0x1
#         \--- LANG [9,1][LANG_ENGLISH,SUBLANG_ENGLISH_US]
#           [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#           0x14A220   0x0   Name:                          0x409
#           0x14A224   0x4   OffsetToData:                  0x2BB8
#             [IMAGE_RESOURCE_DATA_ENTRY]
#             0x14C1B8   0x0   OffsetToData:                  0x209818
#             0x14C1BC   0x4   Size:                          0x45DE
#             0x14C1C0   0x8   CodePage:                      0x0
#             0x14C1C4   0xC   Reserved:                      0x0
#       Id: [0x79]
#       [IMAGE_RESOURCE_DIRECTORY_ENTRY]
#       0x1496A0   0x0   Name:                          0x79
#       0x1496A4   0x4   OffsetToData:                  0x80000C28
#         [IMAGE_RESOURCE_DIRECTORY]
#         0x14A228   0x0   Characteristics:               0x0
#         0x14A22C   0x4   TimeDateStamp:                 0x0        [Thu Jan  1 00:00:00 1970 UTC]
#         0x14A230   0x8   MajorVersion:                  0x0
#         0x14A232   0xA   MinorVersion:                  0x0
# ...
#     00122878h DIR64
#     00122888h DIR64
#     00122898h DIR64
#     001228A8h DIR64
#     001228B8h DIR64
#     001228C8h DIR64
#     001228D8h DIR64
#     001228E8h DIR64
#     001228F8h DIR64
#     00122908h DIR64
#     00122918h DIR64
#     00122928h DIR64
#     00122938h DIR64
#     00122948h DIR64
#     00122958h DIR64
#     00122968h DIR64
#     00122978h DIR64
#     00122988h DIR64
#     00122998h DIR64
#     001229A8h DIR64
#     001229B8h DIR64
#     001229C8h DIR64
#     001229D8h DIR64
#     001229E8h DIR64
#     001229F8h DIR64
#     00122A08h DIR64
#     00122A18h DIR64
#     00122A28h DIR64
#     00122A38h DIR64
#     00122A48h DIR64
#     00122A58h DIR64
#     00122A68h DIR64
#     00122A78h DIR64
#     00122A88h DIR64
#     00122A98h DIR64
#     00122AA8h DIR64
#     00122AB8h DIR64
#     00122AC8h DIR64
#     00122AD8h DIR64
#     00122AE8h DIR64
#     00122AF8h DIR64
#     00122B08h DIR64
#     00122B18h DIR64
#     00122B28h DIR64
#     00122B38h DIR64
#     00122B48h DIR64
#     00122B58h DIR64
#     00122B68h DIR64
#     00122B78h DIR64
#     00122B88h DIR64
#     00122B98h DIR64
#     00122BA8h DIR64
#     00122BB8h DIR64
#     00122BC8h DIR64
#     00122BD8h DIR64
#     00122BE8h DIR64
#     00122BF8h DIR64
#     00122C08h DIR64
#     00122C18h DIR64
#     00122C28h DIR64
#     00122C38h DIR64
#     00122C48h DIR64
#     00122C58h DIR64
#     00122C68h DIR64
#     00122C78h DIR64
#     00122C88h DIR64
#     00122C98h DIR64
#     00122CA8h DIR64
#     00122CB8h DIR64
#     00122CC8h DIR64
#     00122CD8h DIR64
#     00122CE8h DIR64
#     00122CF8h DIR64
#     00122D08h DIR64
#     00122D18h DIR64
#     00122D28h DIR64
#     00122D38h DIR64
#     00122D48h DIR64
#     00122D58h DIR64
#     00122D68h DIR64
#     00122D78h DIR64
#     00122D88h DIR64
#     00122D98h DIR64
#     00122DA8h DIR64
#     00122DB8h DIR64
#     00122DC8h DIR64
#     00122DD8h DIR64
#     00122DE8h DIR64
#     00122DF8h DIR64
#     00122E08h DIR64
#     00122E18h DIR64
#     00122E28h DIR64
#     00122E38h DIR64
#     00122E48h DIR64
#     00122E58h DIR64
#     00122E68h DIR64
#     00122E78h DIR64
#     00122E88h DIR64
#     00122E98h DIR64
#     00122EA8h DIR64
#     00122EB8h DIR64
#     00122EC8h DIR64
#     00122ED8h DIR64
#     00122EE8h DIR64
#     00122EF8h DIR64
#     00122F08h DIR64
#     00122F18h DIR64
#     00122F28h DIR64
#     00122F38h DIR64
#     00122F48h DIR64
#     00122F58h DIR64
#     00122F68h DIR64
#     00122F78h DIR64
#     00122F88h DIR64
#     00122F98h DIR64
#     00122FA8h DIR64
#     00122FB8h DIR64
#     00122FC8h DIR64
#     00122FD8h DIR64
#     00122FE8h DIR64
#     00122FF8h DIR64
#
# [IMAGE_BASE_RELOCATION]
# 0x2280F4   0x0   VirtualAddress:                0x123000
# 0x2280F8   0x4   SizeOfBlock:                   0xA4
#     00123008h DIR64
#     00123018h DIR64
#     00123028h DIR64
#     00123038h DIR64
#     00123048h DIR64
#     00123058h DIR64
#     00123068h DIR64
#     00123078h DIR64
#     00123088h DIR64
#     00123098h DIR64
#     001230A8h DIR64
#     001230B8h DIR64
#     001230C8h DIR64
#     001230D8h DIR64
#     001230E8h DIR64
#     001230F8h DIR64
#     00123108h DIR64
#     00123118h DIR64
#     00123128h DIR64
#     00123138h DIR64
#     00123148h DIR64
#     00123158h DIR64
#     00123168h DIR64
#     00123178h DIR64
#     00123188h DIR64
#     00123198h DIR64
#     001231A8h DIR64
#     001231B8h DIR64
#     001231C8h DIR64
#     001231D8h DIR64
#     001231E8h DIR64
#     001231F8h DIR64
#     00123208h DIR64
#     00123218h DIR64
#     00123228h DIR64
#     00123238h DIR64
#     00123248h DIR64
#     00123258h DIR64
#     00123268h DIR64
#     00123278h DIR64
#     00123288h DIR64
#     00123298h DIR64
#     001232A8h DIR64
#     001232B8h DIR64
#     001232C8h DIR64
#     001232D8h DIR64
#     001232E8h DIR64
#     001232F8h DIR64
#     00123308h DIR64
#     00123318h DIR64
#     00123328h DIR64
#     00123338h DIR64
#     00123348h DIR64
#     00123358h DIR64
#     00123368h DIR64
#     00123378h DIR64
#     00123388h DIR64
#     00123398h DIR64
#     001233A8h DIR64
#     001233B8h DIR64
#     001233C8h DIR64
#     001233D8h DIR64
#     001233E8h DIR64
#     001233F8h DIR64
#     00123408h DIR64
#     00123418h DIR64
#     00123428h DIR64
#     00123438h DIR64
#     00123448h DIR64
#     00123458h DIR64
#     00123468h DIR64
#     00123478h DIR64
#     00123488h DIR64
#     00123498h DIR64
#     001234A8h DIR64
#     001234B8h DIR64
#     001234C8h DIR64
#     001234D8h DIR64
#
# [IMAGE_BASE_RELOCATION]
# 0x228198   0x0   VirtualAddress:                0x124000
# 0x22819C   0x4   SizeOfBlock:                   0x1D0
#     001240F0h DIR64
#     00124100h DIR64
#     00124110h DIR64
#     00124120h DIR64
#     00124130h DIR64
#     00124140h DIR64
#     00124150h DIR64
#     00124160h DIR64
#     00124170h DIR64
#     00124180h DIR64
#     00124190h DIR64
#     001241A0h DIR64
#     001241B0h DIR64
#     001241C0h DIR64
#     001241D0h DIR64
#     001241E0h DIR64
#     001241F0h DIR64
#     00124200h DIR64
#     00124210h DIR64
#     00124220h DIR64
#     00124230h DIR64
#     00124240h DIR64
#     00124250h DIR64
#     00124260h DIR64
#     00124270h DIR64
#     00124280h DIR64
#     00124290h DIR64
#     001242A0h DIR64
#     001242B0h DIR64
#     001242C0h DIR64
#     001242D0h DIR64
#     001242E0h DIR64
#     001242F0h DIR64
#     00124300h DIR64
#     00124310h DIR64
#     00124320h DIR64
#     00124330h DIR64
#     00124340h DIR64
#     00124350h DIR64
#     00124360h DIR64
#     00124370h DIR64
#     00124380h DIR64
#     00124390h DIR64
#     001243A0h DIR64
#     001243B0h DIR64
#     001243C0h DIR64
#     001243D0h DIR64
#     001243E0h DIR64
#     001243F0h DIR64
#     00124400h DIR64
#     00124410h DIR64
#     00124420h DIR64
#     00124430h DIR64
#     00124440h DIR64
#     00124450h DIR64
#     00124460h DIR64
#     00124470h DIR64
#     00124480h DIR64
#     00124490h DIR64
#     001244A0h DIR64
#     001244B0h DIR64
#     001244C0h DIR64
#     001244D0h DIR64
#     001244E0h DIR64
#     001244F0h DIR64
#     00124500h DIR64
#     00124510h DIR64
#     00124520h DIR64
#     00124530h DIR64
#     00124540h DIR64
#     00124550h DIR64
#     00124560h DIR64
#     00124570h DIR64
#     00124580h DIR64
#     00124590h DIR64
#     001245A0h DIR64
#     001245B0h DIR64
#     001245C0h DIR64
#     001245D0h DIR64
#     001245E0h DIR64
#     001245F0h DIR64
#     00124600h DIR64
#     00124610h DIR64
#     00124620h DIR64
#     00124630h DIR64
#     00124640h DIR64
#     00124650h DIR64
#     00124660h DIR64
#     00124670h DIR64
#     00124680h DIR64
#     00124690h DIR64
#     001246A0h DIR64
#     001246B0h DIR64
#     001246C0h DIR64
#     001246D0h DIR64
#     001246E0h DIR64
#     001246F0h DIR64
#     00124700h DIR64
#     00124710h DIR64
#     00124720h DIR64
#     00124730h DIR64
#     00124740h DIR64
#     00124750h DIR64
#     00124760h DIR64
#     00124770h DIR64
#     00124780h DIR64
#     00124790h DIR64
#     001247A0h DIR64
#     001247B0h DIR64
#     001247C0h DIR64
#     001247D0h DIR64
#     001247E0h DIR64
#     001247F0h DIR64
#     00124800h DIR64
#     00124810h DIR64
#     00124820h DIR64
#     00124830h DIR64
#     00124840h DIR64
#     00124850h DIR64
#     00124860h DIR64
#     00124870h DIR64
#     00124880h DIR64
#     00124890h DIR64
#     001248A0h DIR64
#     001248B0h DIR64
#     001248C0h DIR64
#     001248D0h DIR64
#     001248E0h DIR64
#     001248F0h DIR64
#     00124900h DIR64
#     00124910h DIR64
#     00124920h DIR64
#     00124930h DIR64
#     00124940h DIR64
#     00124950h DIR64
#     00124960h DIR64
#     00124970h DIR64
#     00124980h DIR64
#     00124990h DIR64
#     001249A0h DIR64
#     001249B0h DIR64
#     001249C0h DIR64
#     001249D0h DIR64
#     001249E0h DIR64
#     001249F0h DIR64
#     00124A00h DIR64
#     00124A10h DIR64
#     00124A20h DIR64
#     00124A30h DIR64
#     00124A40h DIR64
#     00124A50h DIR64
#     00124A60h DIR64
#     00124A70h DIR64
#     00124A80h DIR64
#     00124A90h DIR64
#     00124AA0h DIR64
#     00124AB0h DIR64
#     00124AC0h DIR64
#     00124AD0h DIR64
#     00124AE0h DIR64
#     00124AF0h DIR64
#     00124B00h DIR64
#     00124B10h DIR64
#     00124B20h DIR64
#     00124B30h DIR64
#     00124B40h DIR64
#     00124B50h DIR64
#     00124B60h DIR64
#     00124B70h DIR64
#     00124B80h DIR64
#     00124B90h DIR64
#     00124BA0h DIR64
#     00124BB0h DIR64
#     00124BC0h DIR64
#     00124BD0h DIR64
#     00124BE0h DIR64
#     00124BF0h DIR64
#     00124C00h DIR64
#     00124C10h DIR64
#     00124C20h DIR64
#     00124C30h DIR64
#     00124C40h DIR64
#     00124C50h DIR64
#     00124C60h DIR64
#     00124C70h DIR64
#     00124C80h DIR64
#     00124C90h DIR64
#     00124CA0h DIR64
#     00124CB0h DIR64
#     00124CC0h DIR64
#     00124CD0h DIR64
#     00124CE0h DIR64
#     00124CF0h DIR64
#     00124D00h DIR64
#     00124D10h DIR64
#     00124D20h DIR64
#     00124D30h DIR64
#     00124D40h DIR64
#     00124D50h DIR64
#     00124D60h DIR64
#     00124D70h DIR64
#     00124D80h DIR64
#     00124D90h DIR64
#     00124DA0h DIR64
#     00124DB0h DIR64
#     00124DC0h DIR64
#     00124DD0h DIR64
#     00124DE0h DIR64
#     00124DF0h DIR64
#     00124E00h DIR64
#     00124E10h DIR64
#     00124E20h DIR64
#     00124E30h DIR64
#     00124E40h DIR64
#     00124E50h DIR64
#     00124E60h DIR64
#     00124E70h DIR64
#     00124E80h DIR64
#     00124E90h DIR64
#     00124EA0h DIR64
#     00124EB0h DIR64
#     00124EC0h DIR64
#     00124ED0h DIR64
#     00124EE0h DIR64
#     00124EF0h DIR64
#     00124F00h DIR64
#     00124F10h DIR64
#     00124F20h DIR64
#
# [IMAGE_BASE_RELOCATION]
# 0x228368   0x0   VirtualAddress:                0x127000
# 0x22836C   0x4   SizeOfBlock:                   0x18
#     001274F8h DIR64
#     00127510h DIR64
#     00127518h DIR64
#     00127538h DIR64
#     00127540h DIR64
#     00127548h DIR64
#     00127550h DIR64
#     00127000h ABSOLUTE
#
# [IMAGE_BASE_RELOCATION]
# 0x228380   0x0   VirtualAddress:                0x13D000
# 0x228384   0x4   SizeOfBlock:                   0xEC
#     0013D000h DIR64
#     0013D008h DIR64
#     0013D010h DIR64
#     0013D018h DIR64
#     0013D058h DIR64
#     0013D300h DIR64
#     0013D308h DIR64
#     0013D310h DIR64
#     0013D318h DIR64
#     0013D320h DIR64
#     0013D328h DIR64
#     0013D330h DIR64
#     0013D338h DIR64
#     0013D340h DIR64
#     0013D348h DIR64
#     0013D350h DIR64
#     0013D358h DIR64
#     0013D360h DIR64
#     0013D368h DIR64
#     0013D370h DIR64
#     0013DB90h DIR64
#     0013DB98h DIR64
#     0013DBA0h DIR64
#     0013DBA8h DIR64
#     0013DBB0h DIR64
#     0013DBB8h DIR64
#     0013DBC0h DIR64
#     0013DBC8h DIR64
#     0013DBD0h DIR64
#     0013DBD8h DIR64
#     0013DBE0h DIR64
#     0013DBE8h DIR64
#     0013DBF0h DIR64
#     0013DBF8h DIR64
#     0013DC00h DIR64
#     0013DC08h DIR64
#     0013DC10h DIR64
#     0013DC18h DIR64
#     0013DC20h DIR64
#     0013DC28h DIR64
#     0013DC30h DIR64
#     0013DC38h DIR64
#     0013DC40h DIR64
#     0013DC48h DIR64
#     0013DC50h DIR64
#     0013DC58h DIR64
#     0013DC60h DIR64
#     0013DC68h DIR64
#     0013DC70h DIR64
#     0013DC78h DIR64
#     0013DC80h DIR64
#     0013DC88h DIR64
#     0013DC90h DIR64
#     0013DC98h DIR64
#     0013DCA0h DIR64
#     0013DCA8h DIR64
#     0013DCB0h DIR64
#     0013DCB8h DIR64
#     0013DCC0h DIR64
#     0013DCC8h DIR64
#     0013DCD0h DIR64
#     0013DCD8h DIR64
#     0013DCE0h DIR64
#     0013DCE8h DIR64
#     0013DCF0h DIR64
#     0013DCF8h DIR64
#     0013DD00h DIR64
#     0013DD08h DIR64
#     0013DD10h DIR64
#     0013DD18h DIR64
#     0013DD20h DIR64
#     0013DD28h DIR64
#     0013DD30h DIR64
#     0013DD38h DIR64
#     0013DD40h DIR64
#     0013DD48h DIR64
#     0013DDF0h DIR64
#     0013DDF8h DIR64
#     0013DE00h DIR64
#     0013DE08h DIR64
#     0013DE10h DIR64
#     0013DE18h DIR64
#     0013DE20h DIR64
#     0013DE28h DIR64
#     0013DE30h DIR64
#     0013DE38h DIR64
#     0013DE40h DIR64
#     0013DE48h DIR64
#     0013DE50h DIR64
#     0013DE58h DIR64
#     0013DE60h DIR64
#     0013DE68h DIR64
#     0013DE70h DIR64
#     0013DED0h DIR64
#     0013DED8h DIR64
#     0013DEE0h DIR64
#     0013DEE8h DIR64
#     0013DEF0h DIR64
#     0013DEF8h DIR64
#     0013DF00h DIR64
#     0013DF08h DIR64
#     0013DF10h DIR64
#     0013DF18h DIR64
#     0013DF20h DIR64
#     0013DF28h DIR64
#     0013DF30h DIR64
#     0013DF38h DIR64
#     0013DF40h DIR64
#     0013DF48h DIR64
#     0013DF50h DIR64
#     0013DFE0h DIR64
#     0013DFE8h DIR64
#     0013DFF0h DIR64
#     0013DFF8h DIR64
#
# [IMAGE_BASE_RELOCATION]
# 0x22846C   0x0   VirtualAddress:                0x13E000
# 0x228470   0x4   SizeOfBlock:                   0x44
#     0013E000h DIR64
#     0013E008h DIR64
#     0013E010h DIR64
#     0013E018h DIR64
#     0013E020h DIR64
#     0013E028h DIR64
#     0013E030h DIR64
#     0013E038h DIR64
#     0013E040h DIR64
#     0013E048h DIR64
#     0013E050h DIR64
#     0013E058h DIR64
#     0013E060h DIR64
#     0013E080h DIR64
#     0013E088h DIR64
#     0013E090h DIR64
#     0013E098h DIR64
#     0013E0A0h DIR64
#     0013E0A8h DIR64
#     0013E0C0h DIR64
#     0013E0E8h DIR64
#     0013E110h DIR64
#     0013E138h DIR64
#     0013E160h DIR64
#     0013E188h DIR64
#     0013E1B0h DIR64
#     0013E1D8h DIR64
#     0013E200h DIR64
#     0013E240h DIR64
#     0013EEB0h DIR64
#
# [IMAGE_BASE_RELOCATION]
# 0x2284B0   0x0   VirtualAddress:                0x13F000
# 0x2284B4   0x4   SizeOfBlock:                   0xF0
#     0013F340h DIR64
#     0013F378h DIR64
#     0013F380h DIR64
#     0013F388h DIR64
#     0013F390h DIR64
#     0013F398h DIR64
#     0013F3A0h DIR64
#     0013F3A8h DIR64
#     0013F3B0h DIR64
#     0013F3B8h DIR64
#     0013F3C0h DIR64
#     0013F3C8h DIR64
#     0013F3D0h DIR64
#     0013F3D8h DIR64
#     0013F3E0h DIR64
#     0013F3E8h DIR64
#     0013F3F0h DIR64
#     0013F3F8h DIR64
#     0013F410h DIR64
#     0013F448h DIR64
#     0013F460h DIR64
#     0013F4A8h DIR64
#     0013F4C0h DIR64
#     0013F508h DIR64
#     0013F520h DIR64
#     0013F568h DIR64
#     0013F580h DIR64
#     0013F5C8h DIR64
#     0013F5E0h DIR64
#     0013F628h DIR64
#     0013F640h DIR64
#     0013F688h DIR64
#     0013F6A0h DIR64
#     0013F6E8h DIR64
#     0013F700h DIR64
#     0013F748h DIR64
#     0013F760h DIR64
#     0013F7A8h DIR64
#     0013F7C0h DIR64
#     0013F808h DIR64
#     0013F820h DIR64
#     0013F868h DIR64
#     0013F880h DIR64
#     0013F8C8h DIR64
#     0013F8E0h DIR64
#     0013F928h DIR64
#     0013F940h DIR64
#     0013F988h DIR64
#     0013F9A0h DIR64
#     0013F9E8h DIR64
#     0013FA00h DIR64
#     0013FA48h DIR64
#     0013FA60h DIR64
#     0013FAA8h DIR64
#     0013FAC0h DIR64
#     0013FB08h DIR64
#     0013FB20h DIR64
#     0013FB68h DIR64
#     0013FB80h DIR64
#     0013FC10h DIR64
#     0013FC18h DIR64
#     0013FC20h DIR64
#     0013FC28h DIR64
#     0013FC30h DIR64
#     0013FC38h DIR64
#     0013FC40h DIR64
#     0013FC48h DIR64
#     0013FC50h DIR64
#     0013FC58h DIR64
#     0013FC60h DIR64
#     0013FC68h DIR64
#     0013FC70h DIR64
#     0013FC78h DIR64
#     0013FC80h DIR64
#     0013FC88h DIR64
#     0013FC90h DIR64
#     0013FC98h DIR64
#     0013FCA0h DIR64
#     0013FCA8h DIR64
#     0013FCB0h DIR64
#     0013FCB8h DIR64
#     0013FCC0h DIR64
#     0013FCC8h DIR64
#     0013FCD0h DIR64
#     0013FCD8h DIR64
#     0013FCE0h DIR64
#     0013FCE8h DIR64
#     0013FCF0h DIR64
#     0013FCF8h DIR64
#     0013FD00h DIR64
#     0013FD08h DIR64
#     0013FD10h DIR64
#     0013FD18h DIR64
#     0013FD20h DIR64
#     0013FD28h DIR64
#     0013FD58h DIR64
#     0013FD60h DIR64
#     0013FD78h DIR64
#     0013FD80h DIR64
#     0013FD98h DIR64
#     0013FDA0h DIR64
#     0013FDB8h DIR64
#     0013FDC0h DIR64
#     0013FDD8h DIR64
#     0013FDE0h DIR64
#     0013FDF8h DIR64
#     0013FE00h DIR64
#     0013FE18h DIR64
#     0013FE20h DIR64
#     0013FE38h DIR64
#     0013FE40h DIR64
#     0013FE58h DIR64
#     0013FE60h DIR64
#     0013FE78h DIR64
#     0013FE80h DIR64
#     0013F000h ABSOLUTE
#
# [IMAGE_BASE_RELOCATION]
# 0x2285A0   0x0   VirtualAddress:                0x141000
# 0x2285A4   0x4   SizeOfBlock:                   0x74
#     00141018h DIR64
#     00141020h DIR64
#     00141028h DIR64
#     00141030h DIR64
#     00141060h DIR64
#     00141068h DIR64
#     00141070h DIR64
#     001411D0h DIR64
#     001411D8h DIR64
#     001411E0h DIR64
#     001411F8h DIR64
#     00141200h DIR64
#     00141208h DIR64
#     00141220h DIR64
#     00141230h DIR64
#     00141530h DIR64
#     00141578h DIR64
#     00141598h DIR64
#     001415B8h DIR64
#     001415D8h DIR64
#     001415F8h DIR64
#     00141628h DIR64
#     00141640h DIR64
#     00141648h DIR64
#     00141650h DIR64
#     00141688h DIR64
#     00141690h DIR64
#     001416E0h DIR64
#     00141918h DIR64
#     00141C30h DIR64
#     00141C38h DIR64
#     00141C40h DIR64
#     00141C48h DIR64
#     00141C50h DIR64
#     00141C58h DIR64
#     00141C60h DIR64
#     00141C68h DIR64
#     00141C70h DIR64
#     00141C78h DIR64
#     00141C88h DIR64
#     00141C90h DIR64
#     00141C98h DIR64
#     00141CA0h DIR64
#     00141CA8h DIR64
#     00141CB0h DIR64
#     00141CB8h DIR64
#     00141CC0h DIR64
#     00141CF8h DIR64
#     00141D18h DIR64
#     00141D40h DIR64
#     00141D68h DIR64
#     00141D80h DIR64
#     00141DA0h DIR64
#     00141DD0h DIR64

# %% [markdown]
# To get file header information in a simpler way, it is recommended to use the dict (*pe.dump_dict()*) which is used to print previous example. This step help us to build an attribute vector that can be used to extract features for our machine learning models further.

# %%
# pe.dump_dict() return a dict used to build the string from previous example
for k, v in pe.dump_dict()['FILE_HEADER'].items():
    # check if it is a dict to get its value
    if isinstance(v,dict):
        print("{}: {}".format(k, v["Value"]))
# Out:
# Characteristics: 34
# NumberOfSections: 8
# TimeDateStamp: 0x5C72EA4B [Sun Feb 24 19:02:35 2019 UTC]
# PointerToSymbolTable: 0
# Machine: 34404
# NumberOfSymbols: 0
# SizeOfOptionalHeader: 240

# %% [markdown]
# #### Exercise:
# Based on samples presented, create a Python method that extract attributes from a single PE file, returning a list of attributes. After that, extract the attributes from all files located at './datasets/samples/pe/' and create an attributes matrix.

# %%
from glob import glob
# data path
path = "./datasets/samples/pe/*.exe"
# get list of files
files = glob(path)
# method to extract attributes fro ma single file
def extract_attributes(file):
    # continue here...
    return
